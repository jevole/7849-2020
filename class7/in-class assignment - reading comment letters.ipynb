# %%
import glob, re
import nltk
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.collocations import *

import string
stopWords = set(stopwords.words('english') ) 

# files holds a list with elements each being a path to a html file
# assumes the folder is in the same folder as this jupyter notebook
files = glob.glob('letters_text/*.txt')

allFiles= []
for file in files[0:20]:
    # read file
    with open( file, encoding='utf-8') as f:
        content = f.read()
    file_tokens = [x for x in word_tokenize(content) if x.lower() not in stopWords and x not in string.punctuation]
    # now we can use nltk functions on the text
    fdist = FreqDist(file_tokens)
    print(fdist)
    print ('most common words in this letter', fdist.most_common(15) )
    # add it to the list of all files
    allFiles.append( file_tokens )
# Out:
# <FreqDist with 899 samples and 4215 outcomes>
# most common words in this letter [('tax', 208), ('deferred', 137), ('assets', 100), ('TRA', 77), ('income', 67), ('million', 57), ('LP', 53), ('2016', 51), ('future', 44), ('amount', 43), ('taxable', 38), ('valuation', 38), ('allowance', 37), ('’', 35), ('Units', 33)]
# <FreqDist with 377 samples and 821 outcomes>
# most common words in this letter [('tax', 29), ('December', 16), ('31', 15), ('2015', 13), ('deferred', 11), ('taxable', 10), ('recognized', 10), ('year', 9), ('asset', 9), ('2016', 8), ('ended', 8), ('differences', 8), ('’', 7), ('future', 7), ('profits', 7)]
# <FreqDist with 194 samples and 289 outcomes>
# most common words in this letter [('tax', 10), ('Company', 7), ('’', 6), ('2017', 4), ('1', 4), ('response', 4), ('benefits', 4), ('Form', 3), ('10-K', 3), ('year', 3), ('ended', 3), ('December', 3), ('31', 3), ('2016', 3), ('letter', 3)]
# <FreqDist with 310 samples and 573 outcomes>
# most common words in this letter [('Company', 12), ('Amendment', 11), ('2', 11), ('“', 10), ('”', 10), ('disclosure', 10), ('Securities', 9), ('Staff', 9), ('Registration', 8), ('Statement', 8), ('page', 8), ('’', 7), ('revised', 7), ('response', 7), ('Guggenheim', 7)]
# <FreqDist with 379 samples and 741 outcomes>
# most common words in this letter [('Company', 18), ('disclosure', 16), ('“', 15), ('”', 15), ('Amendment', 14), ('3', 13), ('page', 13), ('2017', 12), ('Staff', 10), ('’', 8), ('comment', 8), ('pending', 8), ('Response', 7), ('Mining', 7), ('response', 7)]
# <FreqDist with 317 samples and 671 outcomes>
# most common words in this letter [("''", 32), ('2016', 17), ('100', 9), ('style=', 8), ('``', 8), ('width=', 8), ('inferred', 8), ('border=0', 7), ('December', 7), ('31', 7), ('TABLE', 6), ('BORDER-COLOR', 6), ('black', 6), ('FONT-SIZE', 6), ('10pt', 6)]
# <FreqDist with 306 samples and 613 outcomes>
# most common words in this letter [('“', 14), ('”', 14), ('Commission', 9), ('response', 9), ('Securities', 8), ('Exchange', 8), ('Partnership', 8), ('Staff', 8), ('’', 8), ('comment', 7), ('consolidated', 7), ('2016', 6), ('8point3', 6), ('SunPower', 6), ('Form', 5)]
# <FreqDist with 278 samples and 593 outcomes>
# most common words in this letter [('Staff', 12), ('cash', 12), ('Senior', 11), ('subsidiaries', 10), ('Company', 9), ('“', 8), ('”', 8), ('’', 8), ('foreign', 8), ('December', 7), ('31', 7), ('earnings', 7), ('U.S.', 6), ('Commission', 6), ('2015', 6)]
# <FreqDist with 359 samples and 582 outcomes>
# most common words in this letter [('Target', 11), ('U.S.', 9), ('outside', 8), ('ASC', 7), ('million', 7), ('revenues', 7), ('January', 6), ('operations', 6), ('countries', 6), ('long-lived', 6), ('assets', 6), ('28', 5), ('2017', 5), ('depreciation', 5), ('income', 5)]
# <FreqDist with 329 samples and 651 outcomes>
# most common words in this letter [('Fund', 33), ('“', 19), ('”', 19), ('’', 12), ('assets', 10), ('Investment', 7), ('may', 7), ('Class', 7), ('Principal', 6), ('investment', 6), ('basis', 6), ('advisory', 6), ('net', 6), ('2017', 5), ('MLP', 5)]
# <FreqDist with 404 samples and 823 outcomes>
# most common words in this letter [('properties', 27), ('Company', 24), ('acquired', 18), ('business', 10), ('assets', 10), ('20', 9), ('2015', 9), ('December', 7), ('31', 7), ('``', 7), ("''", 7), ('Consolidated', 7), ("'s", 7), ('fiscal', 6), ('year', 6)]
# <FreqDist with 349 samples and 622 outcomes>
# most common words in this letter [('Cash', 18), ('less', 11), ('cash', 10), ('Composition', 10), ('Free', 9), ('Activities', 9), ('“', 8), ('”', 8), ('Flow', 8), ('Spending', 8), ('Company', 6), ('results', 6), ('John', 5), ('Commission', 5), ('2016', 5)]
# <FreqDist with 259 samples and 726 outcomes>
# most common words in this letter [('“', 38), ('”', 38), ('fund', 25), ('Investment', 21), ('Fund', 16), ('Arizona', 15), ('Principal', 14), ('securities', 13), ('disclosure', 12), ('Municipal', 10), ('Fidelity', 9), ('Money', 9), ('Market', 9), ('market', 9), ('prospectus', 8)]
# <FreqDist with 410 samples and 896 outcomes>
# most common words in this letter [('EMC', 33), ('tax', 28), ('Company', 17), ('merger', 17), ('repatriation', 16), ('cash', 16), ('’', 15), ('basis', 12), ('staff', 11), ('registration', 10), ('statement', 10), ('material', 9), ('2016', 8), ('Esq', 8), ('Denali', 8)]
# <FreqDist with 380 samples and 680 outcomes>
# most common words in this letter [('Fund', 33), ('section', 13), ('’', 11), ('made', 9), ('requested', 9), ('may', 8), ('state', 8), ('liquidity', 8), ('30', 7), ('fee', 7), ('comments', 6), ('fund', 6), ('consider', 6), ('disclosure', 6), ('“', 5)]
# <FreqDist with 299 samples and 686 outcomes>
# most common words in this letter [('fiscal', 16), ('2016', 15), ('Company', 15), ('revenues', 14), ('acquisition', 13), ('2017', 12), ('earnings', 12), ('Staff', 9), ('income', 9), ('June', 8), ('30', 8), ('’', 8), ('provide', 7), ('year', 7), ('us', 6)]
# <FreqDist with 312 samples and 680 outcomes>
# most common words in this letter [('’', 22), ('financial', 15), ('Company', 12), ('Registration', 10), ('Statement', 10), ('SONA', 10), ('opinion', 9), ('FIG', 8), ('Partners', 8), ('total', 8), ('“', 7), ('”', 7), ('EVBS', 7), ('provided', 7), ('Staff', 6)]
# <FreqDist with 330 samples and 640 outcomes>
# most common words in this letter [('—', 32), ('EBITDA', 12), ('100.0', 10), ('Company', 8), ('costs', 8), ('``', 7), ("''", 7), ('2017', 7), ('measure', 7), ('December', 6), ('Commission', 6), ('comments', 6), ('Staff', 6), ("'s", 6), ('filings', 6)]
# <FreqDist with 347 samples and 654 outcomes>
# most common words in this letter [('page', 17), ('Congaree', 14), ('Carolina', 12), ('Financial', 11), ('’', 11), ('merger', 11), ('disclosure', 11), ('2016', 8), ('“', 8), ('Company', 8), ('”', 8), ('Commission', 7), ('proxy', 7), ('disclose', 6), ('stock', 6)]
# <FreqDist with 340 samples and 732 outcomes>
# most common words in this letter [('Company', 27), ('First', 18), ('’', 18), ('Texas', 16), ('Staff', 13), ('OKSB', 13), ('“', 11), ('”', 11), ('page', 9), ('merger', 8), ('Securities', 7), ('Simmons', 7), ('response', 7), ('Amendment', 7), ('1', 7)]

# %%
allFiles[1]
# Out:
# ['CORRESP',
#  'September',
#  '20',
#  '2016',
#  'VIA',
#  'EDGAR',
#  'Joel',
#  'Parker',
#  'Senior',
#  'Assistant',
#  'Chief',
#  'Accountant',
#  'Offices',
#  'Beverages',
#  'Apparel',
#  'Mining',
#  'Securities',
#  'Exchange',
#  'Commission',
#  '100',
#  'F',
#  'Street',
#  'N.E',
#  'Washington',
#  'D.C.',
#  '20549',
#  'Turquoise',
#  'Hill',
#  'Resources',
#  'Ltd.',
#  'Form',
#  '40-F',
#  'fiscal',
#  'year',
#  'ended',
#  'December',
#  '31',
#  '2015',
#  'Filed',
#  'March',
#  '17',
#  '2016',
#  'Response',
#  'Dated',
#  'July',
#  '28',
#  '2016',
#  'File',
#  '001-32403',
#  'Dear',
#  'Mr.',
#  'Parker',
#  'Turquoise',
#  'Hill',
#  'Resources',
#  'Ltd.',
#  '“',
#  'Company',
#  '”',
#  'hereby',
#  'acknowledges',
#  'receipt',
#  'comment',
#  'letter',
#  'dated',
#  'August',
#  '24',
#  '2016',
#  '“',
#  'Comment',
#  'Letter',
#  '”',
#  'containing',
#  'comments',
#  'respect',
#  'July',
#  '28',
#  '2016',
#  'response',
#  'comment',
#  'letter',
#  'dated',
#  'July',
#  '1',
#  '2016',
#  'staff',
#  '“',
#  'Staff',
#  '”',
#  'Securities',
#  'Exchange',
#  'Commission',
#  'concerning',
#  'captioned',
#  'Form',
#  '40-F',
#  '“',
#  'Form',
#  '40-F',
#  '”',
#  'hereby',
#  'submits',
#  'letter',
#  'response',
#  'Comment',
#  'Letter',
#  'ease',
#  'reference',
#  'Staff',
#  '’',
#  'comments',
#  'reprinted',
#  'followed',
#  'Company',
#  '’',
#  'responses',
#  'Form',
#  '40-F',
#  'fiscal',
#  'year',
#  'ended',
#  'December',
#  '31',
#  '2015',
#  'Exhibit',
#  '99.2',
#  '17',
#  'Income',
#  'Taxes',
#  'page',
#  '40',
#  'Staff',
#  '’',
#  'comment',
#  '1',
#  'acknowledge',
#  'response',
#  'prior',
#  'comment',
#  'two',
#  'Please',
#  'disclose',
#  'nature',
#  'evidence',
#  'supporting',
#  'recognition',
#  '165',
#  'million',
#  'deferred',
#  'tax',
#  'asset',
#  'accordance',
#  'paragraph',
#  '82',
#  'IAS',
#  '12',
#  'Turquoise',
#  'Hill',
#  'Resources',
#  'Ltd.',
#  'Suite',
#  '354',
#  '–',
#  '200',
#  'Granville',
#  'Street',
#  'Vancouver',
#  'BC',
#  'V6C',
#  '1S4',
#  'Canada',
#  '604',
#  '688',
#  '5755',
#  'www.turquoisehill.com',
#  'Response',
#  'Disclosure',
#  'requirements',
#  'IAS',
#  '12',
#  'paragraph',
#  '82',
#  'respect',
#  'disclosure',
#  'requirements',
#  'IAS',
#  '12',
#  'Income',
#  'Taxes',
#  'paragraph',
#  '82',
#  'standard',
#  'requires',
#  'disclosure',
#  'nature',
#  'evidence',
#  'supporting',
#  'recognition',
#  'utilisation',
#  'deferred',
#  'tax',
#  'asset',
#  'dependent',
#  'future',
#  'taxable',
#  'profits',
#  'excess',
#  'profits',
#  'arising',
#  'reversal',
#  'existing',
#  'taxable',
#  'temporary',
#  'differences',
#  'b',
#  'entity',
#  'suffered',
#  'loss',
#  'either',
#  'current',
#  'preceding',
#  'period',
#  'tax',
#  'jurisdiction',
#  'deferred',
#  'tax',
#  'asset',
#  'relates',
#  'Mongolia',
#  'jurisdiction',
#  '165',
#  'million',
#  'deferred',
#  'tax',
#  'asset',
#  'recognized',
#  'December',
#  '31',
#  '2015',
#  'relates',
#  'Company',
#  '’',
#  'principal',
#  'operating',
#  'subsidiary',
#  'Oyu',
#  'Tolgoi',
#  'LLC',
#  'generated',
#  'taxable',
#  'profits',
#  'utilization',
#  'prior',
#  'period',
#  'tax',
#  'losses',
#  'current',
#  'preceding',
#  'periods',
#  'years',
#  'ended',
#  'December',
#  '31',
#  '2015',
#  'December',
#  '31',
#  '2014',
#  'Taxable',
#  'profits',
#  'differ',
#  'Oyu',
#  'Tolgoi',
#  'accounting',
#  'loss',
#  'continuing',
#  'operations',
#  'reported',
#  'years',
#  'ended',
#  'December',
#  '31',
#  '2015',
#  'December',
#  '31',
#  '2014',
#  'note',
#  '3',
#  'Company',
#  '’',
#  'financial',
#  'statements',
#  'year',
#  'ended',
#  'December',
#  '31',
#  '2015',
#  'Operating',
#  'segments',
#  'since',
#  'among',
#  'differences',
#  'tax',
#  'accounting',
#  'bases',
#  'finance',
#  'costs',
#  'accounting',
#  'basis',
#  'include',
#  'intercompany',
#  'interest',
#  'expensed',
#  'yet',
#  'paid',
#  'whereas',
#  'interest',
#  'expense',
#  'deducted',
#  'Mongolia',
#  'tax',
#  'purposes',
#  'upon',
#  'payment',
#  'finance',
#  'costs',
#  'reported',
#  'years',
#  'ended',
#  'December',
#  '31',
#  '2015',
#  'December',
#  '31',
#  '2014',
#  'Oyu',
#  'Tolgoi',
#  'note',
#  '3',
#  'Company',
#  '’',
#  'financial',
#  'statements',
#  'year',
#  'ended',
#  'December',
#  '31',
#  '2015',
#  'substantially',
#  'accrued',
#  'paid',
#  'either',
#  'year',
#  'end',
#  'thus',
#  'expensed',
#  'accounting',
#  'purposes',
#  'resulting',
#  'accounting',
#  'loss',
#  'deducted',
#  'income',
#  'Mongolian',
#  'tax',
#  'purposes',
#  'resulting',
#  'income',
#  'Mongolian',
#  'tax',
#  'purposes',
#  'view',
#  'recent',
#  'taxable',
#  'earnings',
#  'history',
#  'preparing',
#  'financial',
#  'statements',
#  'year',
#  'ended',
#  'December',
#  '31',
#  '2015',
#  'concluded',
#  'disclosure',
#  'nature',
#  'evidence',
#  'supporting',
#  'deferred',
#  'tax',
#  'recognition',
#  'required',
#  'IAS',
#  '12',
#  'paragraph',
#  '82',
#  'required',
#  'Modification',
#  'disclosures',
#  'future',
#  'filings',
#  'Notwithstanding',
#  'response',
#  'comments',
#  'raised',
#  'Staff',
#  'Company',
#  'modify',
#  'disclosures',
#  'future',
#  'Consolidated',
#  'Financial',
#  'Statements',
#  'filed',
#  'Form',
#  '40-F',
#  'respect',
#  'accounting',
#  'policy',
#  'Income',
#  'taxes',
#  'currently',
#  'note',
#  '2',
#  'provided',
#  'changes',
#  'current',
#  'facts',
#  'circumstances',
#  'Income',
#  'taxes',
#  'currently',
#  'note',
#  '17',
#  'set',
#  'forth',
#  'Page',
#  '2',
#  'Deletions',
#  'additions',
#  'existing',
#  'disclosures',
#  'indicated',
#  'strikethrough',
#  'bold',
#  'text',
#  'respectively',
#  'Note',
#  '2',
#  'Taxation',
#  '“',
#  '…enacted',
#  'reporting',
#  'date',
#  'Deferred',
#  'tax',
#  'recognized',
#  'respect',
#  'unused',
#  'tax',
#  'losses',
#  'credits',
#  'well',
#  'temporary',
#  'differences',
#  'carrying',
#  'amounts',
#  'assets',
#  'liabilities',
#  'financial',
#  'reporting',
#  'purposes',
#  'amounts',
#  'used',
#  'taxation',
#  'purposes',
#  'Deferred',
#  'tax',
#  'measured',
#  'tax',
#  'rates',
#  'expected',
#  'applied',
#  'temporary',
#  'differences',
#  'reverse',
#  'based',
#  'enacted',
#  'substantively',
#  'enacted',
#  'laws',
#  'reporting',
#  'date',
#  'deferred',
#  'tax',
#  'asset',
#  'recognized',
#  'unused',
#  'tax',
#  'losses',
#  'tax',
#  'credits',
#  'deductible',
#  'temporary',
#  'differences',
#  'extent',
#  'probable',
#  'future',
#  'taxable',
#  'profits',
#  'available',
#  'utilized',
#  'Future',
#  'taxable',
#  'profits',
#  'estimated',
#  'using',
#  'income',
#  'forecast',
#  'derived',
#  'cash',
#  'flow',
#  'projections',
#  'based',
#  'detailed',
#  'life-of-mine',
#  'and/or',
#  'production',
#  'plans',
#  'applicable',
#  'probability',
#  'utilizing',
#  'tax',
#  'losses',
#  'credits',
#  'evaluated',
#  'considering',
#  'risks',
#  'relevant',
#  'future',
#  'cash',
#  'flows',
#  'expiry',
#  'dates',
#  'losses',
#  'credits',
#  'longer',
#  'utilized',
#  'Deferred',
#  'tax',
#  'recognized',
#  'initial',
#  'recognition',
#  'assets',
#  'liabilities',
#  'transaction',
#  'business',
#  'combination…',
#  '”',
#  'Note',
#  '17',
#  'ii',
#  'Deferred',
#  'tax',
#  'asset',
#  'recognized',
#  '2015',
#  'deferred',
#  'tax',
#  'asset',
#  'xxx.x',
#  'million',
#  'recognized',
#  'December',
#  '31',
#  '2016',
#  'relation',
#  'accrued',
#  'unpaid',
#  'interest',
#  'expense',
#  'tax',
#  'losses',
#  'Mongolia',
#  'subject',
#  'eight',
#  'year',
#  'carry-forward',
#  'limit',
#  'Deferred',
#  'tax',
#  'assets',
#  'arising',
#  'unpaid',
#  'interest',
#  'expense',
#  'accrued',
#  'December',
#  '31',
#  '2016',
#  'recognized',
#  'extent',
#  'recovery',
#  'considered',
#  'probable',
#  'assessing',
#  'probability',
#  'recovery',
#  'taxable',
#  'profit',
#  'projections',
#  'derived',
#  'cash',
#  'flow',
#  'projections',
#  'based',
#  'detailed',
#  'life-of-mine',
#  'production',
#  'plans',
#  'evaluated',
#  'reference',
#  'commodity',
#  'price',
#  'sensitivities',
#  'eight',
#  'year',
#  'carry-forward',
#  'limit',
#  'Recognition',
#  'deferred',
#  'tax',
#  'includes',
#  'adjustments',
#  'previously',
#  'unrecognized',
#  'amounts',
#  'based',
#  'Oyu',
#  'Tolgoi',
#  'LLC',
#  '’',
#  'income',
#  'tax',
#  'rate',
#  'Mongolia',
#  'Page',
#  '3',
#  'deferred',
#  'tax',
#  'asset',
#  '165',
#  'million',
#  'initially',
#  'recognized',
#  'December',
#  '31',
#  '2015',
#  'relation',
#  'accrued',
#  'unpaid',
#  'interest',
#  'expense',
#  'following',
#  'reassessment',
#  'recoverability',
#  'deferred',
#  'tax',
#  'recognized',
#  'previous',
#  'periods',
#  'following',
#  'assessments',
#  'recoverability',
#  'considered',
#  'likelihood',
#  'timing',
#  'restarting',
#  'underground',
#  'mine',
#  'development',
#  'Oyu',
#  'Tolgoi',
#  'December',
#  '14',
#  '2015',
#  'Oyu',
#  'Tolgoi',
#  'signed',
#  '4.4',
#  'billion',
#  'finance',
#  'facility',
#  'together',
#  'signing',
#  'Oyu',
#  'Tolgoi',
#  'Underground',
#  'Mine',
#  'Development',
#  'Financing',
#  'Plan',
#  'May',
#  '18',
#  '2015',
#  'resolved',
#  'matters',
#  'prerequisite',
#  'establishing',
#  'probability',
#  'future',
#  'taxable',
#  'profits',
#  'utilize',
#  'deductible',
#  'temporary',
#  'differences',
#  'related',
#  'accrued',
#  'unpaid',
#  'interest',
#  'expense',
#  'reassessment',
#  'concluded',
#  'view',
#  'increased',
#  'certainty',
#  'underground',
#  'development',
#  'proceeding',
#  'probable',
#  'future',
#  'taxable',
#  'profit',
#  'would',
#  'available',
#  'deductible',
#  'temporary',
#  'differences',
#  'expired',
#  'consequence',
#  'deferred',
#  'tax',
#  'asset',
#  '165',
#  'million',
#  'recognized',
#  'assessing',
#  'probability',
#  'recovery',
#  'taxable',
#  'profit',
#  'projections',
#  'derived',
#  'cash',
#  'flow',
#  'projections',
#  'based',
#  'detailed',
#  'life-of-mine',
#  'production',
#  'plans',
#  'evaluated',
#  'reference',
#  'commodity',
#  'price',
#  'sensitivities',
#  'eight',
#  'year',
#  'carry-forward',
#  'limit',
#  'deductible',
#  'temporary',
#  'differences',
#  'subject',
#  'questions',
#  'additional',
#  'comments',
#  'concerning',
#  'foregoing',
#  'please',
#  'contact',
#  '801',
#  '204-2110',
#  'truly',
#  '/s/',
#  'Steeve',
#  'Thibeault',
#  'Steeve',
#  'Thibeault',
#  'Chief',
#  'Financial',
#  'Officer',
#  'Turquoise',
#  'Hill',
#  'Resources',
#  'Ltd.',
#  'cc',
#  'Brian',
#  'McAllister',
#  'John',
#  'Coleman',
#  'Securities',
#  'Exchange',
#  'Commission',
#  'Edwin',
#  'S.',
#  'Maynard',
#  'Esq.',
#  'David',
#  'E.',
#  'Sobel',
#  'Esq',
#  'Paul',
#  'Weiss',
#  'Rifkind',
#  'Wharton',
#  'Garrison',
#  'LLP',
#  'Page',
#  '4']

# %%
allFiles[1][0:10]
# Out:
# ['CORRESP',
#  'September',
#  '20',
#  '2016',
#  'VIA',
#  'EDGAR',
#  'Joel',
#  'Parker',
#  'Senior',
#  'Assistant']

# %%
file_tokens
# Out:
# ['Letterhead',
#  'Wachtell',
#  'Lipton',
#  'Rosen',
#  'Katz',
#  'September',
#  '13',
#  '2016',
#  'VIA',
#  'HAND',
#  'DELIVERY',
#  'EDGAR',
#  'Suzanne',
#  'Hayes',
#  'Assistant',
#  'Director',
#  'Office',
#  'Healthcare',
#  'Insurance',
#  'Division',
#  'Corporation',
#  'Finance',
#  'U.S.',
#  'Securities',
#  'Exchange',
#  'Commission',
#  '100',
#  'F',
#  'Street',
#  'NE',
#  'Washington',
#  'D.C.',
#  '20549',
#  'Abbott',
#  'Laboratories',
#  'Amendment',
#  '1',
#  'Registration',
#  'Statement',
#  'Form',
#  'S-4',
#  'Filed',
#  'August',
#  '9',
#  '2016',
#  'File',
#  '333-212002',
#  'Dear',
#  'Ms.',
#  'Hayes',
#  'behalf',
#  'client',
#  'Abbott',
#  'Laboratories',
#  '“',
#  'Abbott',
#  '”',
#  '“',
#  'Company',
#  '”',
#  'set',
#  'forth',
#  'responses',
#  'Company',
#  'comments',
#  'Staff',
#  '“',
#  'Staff',
#  '”',
#  'Division',
#  'Corporation',
#  'Finance',
#  'U.S.',
#  'Securities',
#  'Exchange',
#  'Commission',
#  '“',
#  'Commission',
#  '”',
#  'set',
#  'forth',
#  'letter',
#  'dated',
#  'August',
#  '9',
#  '2016',
#  'regarding',
#  'Amendment',
#  '1',
#  'Company',
#  '’',
#  'Registration',
#  'Statement',
#  'Form',
#  'S-4',
#  'filed',
#  'August',
#  '9',
#  '2016',
#  '“',
#  'Registration',
#  'Statement',
#  '”',
#  'connection',
#  'letter',
#  'Company',
#  'filing',
#  'Amendment',
#  '2',
#  'Registration',
#  'Statement',
#  '“',
#  'Amendment',
#  '2',
#  '”',
#  'separately',
#  'furnishing',
#  'Staff',
#  'three',
#  'courtesy',
#  'copies',
#  'Amendment',
#  '2',
#  'marked',
#  'show',
#  'changes',
#  'version',
#  'Registration',
#  'Statement',
#  'filed',
#  'August',
#  '9',
#  '2016',
#  'Capitalized',
#  'terms',
#  'used',
#  'defined',
#  'herein',
#  'meanings',
#  'specified',
#  'Amendment',
#  '2',
#  'convenience',
#  'Staff',
#  '’',
#  'comments',
#  'set',
#  'forth',
#  'bold',
#  'followed',
#  'responses',
#  'Company',
#  'references',
#  'page',
#  'numbers',
#  'responses',
#  'page',
#  'numbers',
#  'Amendment',
#  '2',
#  'Summary',
#  'Financial',
#  'Analyses',
#  'page',
#  '64',
#  'Overview',
#  'Financial',
#  'Analyses',
#  'page',
#  '64',
#  '1',
#  'note',
#  'revised',
#  'disclosure',
#  'response',
#  'prior',
#  'comments',
#  '8',
#  '10',
#  'appears',
#  'certain',
#  'companies',
#  'transactions',
#  'satisfied',
#  'criteria',
#  'used',
#  'excluded',
#  'Selected',
#  'Public',
#  'Companies',
#  'Selected',
#  'Precedent',
#  'Transactions',
#  'analyses',
#  'please',
#  'revise',
#  'explain',
#  'reason',
#  'exclusion',
#  'Also',
#  'revise',
#  'identify',
#  'specifically',
#  'criteria',
#  'used',
#  'select',
#  'companies',
#  'analyses',
#  'instance',
#  'quantify',
#  'range',
#  '“',
#  'large',
#  'cap',
#  '”',
#  'companies',
#  'Guggenheim',
#  'deemed',
#  '“',
#  'generally',
#  'relevant',
#  '”',
#  'purposes',
#  'analyses',
#  'Response',
#  'Company',
#  'supplementally',
#  'advises',
#  'Staff',
#  'Guggenheim',
#  'Securities',
#  'informed',
#  'Company',
#  'Guggenheim',
#  'Securities',
#  'believes',
#  'selected',
#  'companies',
#  'selected',
#  'precedent',
#  'transactions',
#  'included',
#  'analyses',
#  'reflect',
#  'companies',
#  'transactions',
#  'respectively',
#  'professional',
#  'judgment',
#  'met',
#  'selected',
#  'criteria',
#  'response',
#  'Staff',
#  '’',
#  'comment',
#  'disclosure',
#  'Registration',
#  'Statement',
#  'revised',
#  'pages',
#  '67',
#  '69',
#  '71',
#  'Amendment',
#  '2',
#  'clarify',
#  'criteria',
#  'selected',
#  'public',
#  'companies',
#  'selected',
#  'precedent',
#  'transactions',
#  'included',
#  'Guggenheim',
#  'Securities',
#  '’',
#  'analyses',
#  'Selected',
#  'Precedent',
#  'Transactions',
#  'Multiples',
#  'Growth',
#  'Rates',
#  'page',
#  '69',
#  '2',
#  'Please',
#  'remove',
#  'statement',
#  '“',
#  'shown',
#  'informational',
#  'purposes',
#  '”',
#  'chart',
#  'page',
#  '69',
#  'inappropriate',
#  'disclaim',
#  'responsibility',
#  'information',
#  'registration',
#  'statement',
#  'Response',
#  'response',
#  'Staff',
#  '’',
#  'comment',
#  'disclosure',
#  'Registration',
#  'Statement',
#  'revised',
#  'pages',
#  '68',
#  '69',
#  '72',
#  'Amendment',
#  '2',
#  'Company',
#  'supplementally',
#  'advises',
#  'Staff',
#  'Guggenheim',
#  'Securities',
#  'informed',
#  'Company',
#  'revised',
#  'disclosure',
#  'intended',
#  'assist',
#  'readers',
#  'distinguishing',
#  'metrics',
#  'Guggenheim',
#  'Securities',
#  'used',
#  'analytically',
#  'data',
#  'Guggenheim',
#  'Securities',
#  'merely',
#  'provided',
#  'St.',
#  'Jude',
#  'Medical',
#  'board',
#  'directors',
#  'additional',
#  'reference',
#  'points',
#  'Material',
#  'U.S.',
#  'Federal',
#  'Income',
#  'Tax',
#  'Consequences',
#  'page',
#  '186',
#  '3',
#  'note',
#  'revised',
#  'disclosure',
#  'response',
#  'prior',
#  'comment',
#  '19',
#  'describes',
#  'tax',
#  'consequences',
#  'holders',
#  '“',
#  'receive',
#  'Abbott',
#  'shares',
#  'cash',
#  'pursuant',
#  'transaction',
#  'constituting',
#  '‘',
#  'reorganization',
#  '’',
#  'within',
#  'meaning',
#  'Section',
#  '368',
#  'Code.',
#  '”',
#  'acceptable',
#  'merely',
#  'describe',
#  'tax',
#  'treatment',
#  'transactions',
#  'constituting',
#  'reorganizations',
#  'without',
#  'application',
#  'specific',
#  'facts',
#  'particular',
#  'transaction',
#  'Please',
#  'revise',
#  'clarify',
#  'whether',
#  'transaction',
#  'constitute',
#  'reorganization',
#  'tax',
#  'consequences',
#  'currently',
#  'described',
#  'apply',
#  'security',
#  'holders',
#  'transaction',
#  'unable',
#  'provide',
#  'unequivocal',
#  'disclosure',
#  'regarding',
#  'tax',
#  'treatment',
#  'mergers',
#  'disclose',
#  'describing',
#  'degree',
#  'uncertainty',
#  'implications',
#  'event',
#  '2',
#  'transaction',
#  'constitute',
#  'reorganization',
#  'include',
#  'risk',
#  'factor',
#  'disclosure',
#  'Response',
#  'response',
#  'Staff',
#  '’',
#  'comment',
#  'disclosure',
#  'Registration',
#  'Statement',
#  'revised',
#  'page',
#  '188',
#  'Amendment',
#  '2',
#  'Exhibits',
#  '8.1',
#  '8.2',
#  'Amendment',
#  '2',
#  'revised',
#  'response',
#  'request',
#  'Company',
#  'acknowledges',
#  '·',
#  'Company',
#  'responsible',
#  'adequacy',
#  'accuracy',
#  'disclosure',
#  'filing',
#  '·',
#  'staff',
#  'comments',
#  'changes',
#  'disclosure',
#  'response',
#  'staff',
#  'comments',
#  'foreclose',
#  'Commission',
#  'taking',
#  'action',
#  'respect',
#  'filing',
#  '·',
#  'Company',
#  'may',
#  'assert',
#  'staff',
#  'comments',
#  'defense',
#  'proceeding',
#  'initiated',
#  'Commission',
#  'person',
#  'federal',
#  'securities',
#  'laws',
#  'United',
#  'States',
#  'questions',
#  'regarding',
#  'filing',
#  'please',
#  'contact',
#  'undersigned',
#  '212',
#  '403-1394',
#  'Victor',
#  'Goldfeld',
#  '212',
#  '403-1005',
#  'Sebastian',
#  'L.',
#  'Fain',
#  '212',
#  '403-1135',
#  'truly',
#  '/s/',
#  'David',
#  'K.',
#  'Lam',
#  'David',
#  'K.',
#  'Lam',
#  'Enclosures',
#  'cc',
#  'Michael',
#  'Gershon',
#  'Esq',
#  'Mary',
#  'Beth',
#  'Breslin',
#  'Esq.',
#  'U.S.',
#  'Securities',
#  'Exchange',
#  'Commission',
#  'Hubert',
#  'L.',
#  'Allen',
#  'Esq.',
#  'Executive',
#  'Vice',
#  'President',
#  'General',
#  'Counsel',
#  'Secretary',
#  'Abbott',
#  'Laboratories',
#  'Jason',
#  'A.',
#  'Zellers',
#  'Esq.',
#  'Vice',
#  'President',
#  'General',
#  'Counsel',
#  'Corporate',
#  'Secretary',
#  'St.',
#  'Jude',
#  'Medical',
#  'Inc.',
#  'Joseph',
#  'M.',
#  'Barbeau',
#  'Esq.',
#  'Gibson',
#  'Dunn',
#  'Crutcher',
#  'LLP',
#  '3']

# %%
# example collocations (for one document)
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(file_tokens)
sorted(finder.nbest(bigram_measures.raw_freq, 10))
# Out:
# [('9', '2016'),
#  ('Abbott', 'Laboratories'),
#  ('Amendment', '2'),
#  ('August', '9'),
#  ('Exchange', 'Commission'),
#  ('Guggenheim', 'Securities'),
#  ('Registration', 'Statement'),
#  ('Securities', 'Exchange'),
#  ('Staff', '’'),
#  ('Statement', 'revised')]

# %%
# five most frequent collocations (for each letter)
bigram_measures = nltk.collocations.BigramAssocMeasures()

for f in allFiles:
    # set finder
    finder = BigramCollocationFinder.from_words(f)
    # get 5 most frequent
    most = sorted(finder.nbest(bigram_measures.raw_freq, 5))
    print(most)
# Out:
# [('LP', 'Units'), ('deferred', 'tax'), ('tax', 'assets'), ('taxable', 'income'), ('valuation', 'allowance')]
# [('31', '2015'), ('December', '31'), ('deferred', 'tax'), ('ended', 'December'), ('tax', 'asset')]
# [('31', '2016'), ('Company', '’'), ('December', '31'), ('Form', '10-K'), ('tax', 'benefits')]
# [('9', '2016'), ('Amendment', '2'), ('August', '9'), ('Guggenheim', 'Securities'), ('Registration', 'Statement')]
# [('Amendment', '3'), ('CONSOL', 'Mining'), ('Company', 'respectfully'), ('Staff', '’'), ('disclosure', 'page')]
# [("''", '100'), ("''", 'border=0'), ('100', "''"), ('style=', "''"), ('width=', "''")]
# [('30', '2015'), ('Exchange', 'Commission'), ('Form', '10-K'), ('November', '30'), ('Securities', 'Exchange')]
# [('December', '31'), ('Senior', 'Notes'), ('cash', 'cash'), ('cash', 'equivalents'), ('foreign', 'subsidiaries')]
# [('January', '28'), ('attributable', 'countries'), ('countries', 'outside'), ('long-lived', 'assets'), ('outside', 'U.S.')]
# [('Fund', '’'), ('Investment', 'Strategies'), ('New', 'York'), ('Principal', 'Investment'), ('net', 'assets')]
# [('20', 'acquired'), ('Company', "'s"), ('December', '31'), ('acquired', 'properties'), ('properties', 'acquired')]
# [('Cash', 'Flow'), ('Composition', 'Spending'), ('Flow', 'less'), ('Free', 'Cash'), ('less', 'Composition')]
# [('Market', 'Fund'), ('Money', 'Market'), ('Principal', 'Investment'), ('“', 'Principal'), ('”', '“')]
# [('amended', 'registration'), ('registration', 'statement'), ('staff', '’'), ('standalone', 'basis'), ('tax', 'attributes')]
# [('Fees', 'Redemption'), ('Fund', 'may'), ('Fund', 'seeks'), ('Fund', '’'), ('made', 'requested')]
# [('June', '30'), ('Staff', '’'), ('ended', 'June'), ('fiscal', 'year'), ('revenues', 'earnings')]
# [('Amendment', '1'), ('Bancorp', 'Virginia'), ('FIG', 'Partners'), ('Registration', 'Statement'), ('SONA', '’')]
# [('10-K', 'Fiscal'), ('Adjusted', 'EBITDA'), ('December', '31'), ('acquisition', 'related'), ('future', 'filings')]
# [('4', '2016'), ('Alexandra', 'M.'), ('Carolina', 'Financial'), ('proxy', 'statement/prospectus'), ('requested', 'disclosure')]
# [('Amendment', '1'), ('Company', '’'), ('First', 'Texas'), ('OKSB', 'First'), ('Registration', 'Statement')]
